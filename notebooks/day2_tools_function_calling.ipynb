# %% [markdown]
# # Day 2 — Operational Data, Tools & Function Calling
#
# Airport Operations AI Copilot

# %% [markdown]
# ## Objective
#
# Connect the AI copilot to synthetic airport operational data and demonstrate tool calling.

# %%
from src.tools import (\n
    get_airport_metrics,\n
    calculate_driver_incentive,\n
    trigger_surge_override\n
)

# %% [markdown]
# ## 1. Airport Metrics Tool

# %%
get_airport_metrics('SFO')

# %% [markdown]
# ## 2. Driver Incentive Calculator

# %%
calculate_driver_incentive(100, 'high')

# %% [markdown]
# ## 3. Surge Override Tool

# %%
trigger_surge_override(\n
    'SFO',\n
    1.5,\n
    'High request volume and large queue'\n
)

# %% [markdown]
# ## 4. Gemini Function Calling

# %%
from src.agents import ask_operations\n
\n
result = ask_operations(\n
    'What is happening at SFO?'\n
)\n
\n
print(result['answer'])

# %% [markdown]
# ## 5. Error Handling\n
#
# The tools validate airport codes, severity levels, driver counts, surge multipliers, and required parameters.
